# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd. read_csv('cleaned_titanic_after_task1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    775 non-null    int64
#  1   Pclass      775 non-null    float64
#  2   Sex         775 non-null    int64
#  3   Age         775 non-null    float64
#  4   SibSp       775 non-null    float64
#  5   Parch       775 non-null    float64
#  6   Fare        775 non-null    float64
#  7   Embarked_Q  775 non-null    bool
#  8   Embarked_S  775 non-null    bool
# dtypes: bool(2), float64(5), int64(2)
# memory usage: 44.0 KB

# %%
df.head()
# Out:
#    Survived    Pclass  Sex       Age     SibSp     Parch      Fare  \
# 0         0  0.827377    1 -0.565736  0.432793 -0.473674 -0.502445
# 1         1  0.827377    0 -0.258337 -0.474545 -0.473674 -0.488854
# 2         1 -1.566107    0  0.433312  0.432793 -0.473674  0.420730
# 3         0  0.827377    1  0.433312 -0.474545 -0.473674 -0.486337
# 4         0  0.827377    1 -0.104637 -0.474545 -0.473674 -0.478116
#
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False        True
# 2       False        True
# 3       False        True
# 4        True       False

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  775.000000  775.000000  775.000000  775.000000  775.000000  775.000000
# mean     0.339355    0.205071    0.685161   -0.047099   -0.077658   -0.050830
# std      0.473796    0.878875    0.464752    0.982304    0.816458    0.975558
# min      0.000000   -1.566107    0.000000   -2.224156   -0.474545   -0.473674
# 25%      0.000000   -0.369365    0.000000   -0.565736   -0.474545   -0.473674
# 50%      0.000000    0.827377    1.000000   -0.104637   -0.474545   -0.473674
# 75%      1.000000    0.827377    1.000000    0.356462    0.432793   -0.473674
# max      1.000000    0.827377    1.000000    3.891554    4.062148    6.974147
#
#              Fare
# count  775.000000
# mean    -0.289579
# std      0.273391
# min     -0.648422
# 25%     -0.489442
# 50%     -0.386671
# 75%     -0.124920
# max      0.660333

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    512
# 1    263
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# 1    531
# 0    244
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
#  0.827377    484
# -0.369365    179
# -1.566107    112
# Name: count, dtype: int64

# %%
plt.subplot()

# %%
numeric_features = ['Age','Fare','Pclass','SibSp','Parch']

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(numeric_features):
    plt.subplot(2,3,i+1)
    sns.histplot(df[col],kde= True)
    plt.title(f'histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('frequency')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gadda\anaconda3\envs\GHR\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gadda\anaconda3\envs\GHR\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gadda\anaconda3\envs\GHR\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gadda\anaconda3\envs\GHR\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gadda\anaconda3\envs\GHR\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(15,20))
for i,col in enumerate(numeric_features):
    plt.subplot(2,3,i+1)
    sns.boxplot(y=df[col])
    plt.title(f'boxplot of {col}')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix,annot = True,cmap = 'coolwarm',fmt = ".2f",linewidths=.5)
plt.title('correlation matrix of features')
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.barplot(x='Sex', y='Survived', data=df)
plt.title('Survival Rate by Sex')
plt.xlabel('Sex (0=Female, 1=Male if label encoded)')
plt.ylabel('Survival Rate')
# Out:
# Text(0, 0.5, 'Survival Rate')

# %%
plt.subplot(1, 2, 2)
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Pclass')
plt.xlabel('Passenger Class (scaled values if standardized)')
plt.ylabel('Survival Rate')
plt.tight_layout()
plt.show()
